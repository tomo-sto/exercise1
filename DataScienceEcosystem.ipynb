# %% [markdown]
# # Data Science Tools and Ecosystem
# ## 著者
# 石川智也

# %% [markdown]
# このノートブックでは、データサイエンスツールとエコシステムがまとめられています。
# **目的**:
# + データサイエンスのための一般的な言語をリストする。
# + データサイエンスのための一般的なライブラリをリストする。
# + データサイエンスのための一般的なツールをリストする。
# + Pythonの挙動を確認してみる。
#
#
# データサイエンティストが使用する一般的な言語のいくつかは次のとおりです:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala
# 6. Java
# 7. C++
#
# データサイエンティストが使用する一般的なライブラリには次のようなものがあります:
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-learn
# 6. TensorFlow
# 7. PyTorch

# %% [markdown]
# |データサイエンスツール|
# |-------|
# |Jupyter Notebook|
# |RStudio|
# |Apache Spark|

# %% [markdown]
# ### 以下は、Pythonで算術式を評価するいくつかの例です。

# %%
# これは整数を掛けてから加算する簡単な算術式です
(3*4)+5
# Out:
# 17

# %%
# これは200分を60で割って時間に変換します
200 / 60
# Out:
# 3.3333333333333335
